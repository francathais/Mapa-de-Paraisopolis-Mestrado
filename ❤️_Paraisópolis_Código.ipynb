# %% [markdown]
# #Mapa de Paraisópolis

# %%
import folium
import pandas as pd

# %%
# Primeiro criamos o objeto m para o mapa
m = folium.Map(location=[-23.6166846,-46.7301111], zoom_start=16.5)# Depois adicionamos o marcador. 

folium.Marker(location=[-23.6115188,-46.7262597], 
              popup='UBS PARAISÓPOLIS II',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6171104,-46.7245559], 
              popup='União dos Moradores e do Comércio de Paraisópolis',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6151895,-46.7244039], 
              popup='Club Baile da DZ7',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.616312,-46.7244319], 
              popup='CEU Paraisópolis - Marisa Motta, Profa.',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6125562,-46.7358362], 
              popup='Serviço de Assistência Social à Família',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6175182,-46.723615], 
              popup='Arena Palmeirinha',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6183089,-46.7249135], 
              popup='g10 das Favelas',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6147378,-46.7277712], 
              popup='Praça da Cidadania',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6439572,-46.7340918], 
              popup='Metro  Giovanni Gronchi ',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)

folium.Marker(location=[-23.6205531,-46.7122396], 
              popup='Colégio Franciscano Pio XII ',
              icon=folium.Icon(color='pink', icon='info-sign')
).add_to(m)


folium.CircleMarker(
    location=[-23.6152386,-46.7271385],
    radius=260,
    popup='PARAISÓPOLIS',
    color='blue',
    fill=True,
    fill_color='lightblue'
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
